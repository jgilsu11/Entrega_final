# %%
import pandas as pd
import numpy as np



import sys 
import os
import warnings
warnings.filterwarnings("ignore")
sys.path.append(os.path.abspath("../src"))   
import soporte_preprocesamiento as f

pd.set_option('display.max_columns', None)

# %%
df_crudo=pd.read_pickle("../datos/EF/Datos_filtrados/Datos_filtrados.pkl")

# %%
df_crudo.head()
# Out:
#    iden idq_pv            idq_mun  nresi  \
# 0     1  Álava  Municipio_pequeño      1
# 1     2  Álava  Municipio_pequeño      2
# 2     3  Álava  Municipio_pequeño      4
# 3     4  Álava  Municipio_pequeño      1
# 4     5  Álava  Municipio_pequeño      4
#
#                                     regvi                   pagovi  \
# 0  Propia por compra con pagos pendientes  De 200€ a menos de 300€
# 1    Propia por compra totalmente pagada               Desconocido
# 2  Propia por compra con pagos pendientes  De 700€ a menos de 800€
# 3          Propia por herencia o donación              Desconocido
# 4    Propia por compra totalmente pagada               Desconocido
#
#                   tipoagua naseos nsalones ndormito  ... erfotov nviviendp  \
# 0  abastecimiento público       1        1        3  ...      No         4
# 1  abastecimiento público       3        1        3  ...      No         1
# 2  abastecimiento público       4        1        4  ...      No         1
# ...

# %% [markdown]
# Para comprobar que se han mantenido los formatos (por eso lo he guardado en pkl)

# %%
df_crudo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172444 entries, 0 to 172443
# Data columns (total 33 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   iden             172444 non-null  int64
#  1   idq_pv           172444 non-null  object
#  2   idq_mun          172444 non-null  object
#  3   nresi            172444 non-null  int64
#  4   regvi            172444 non-null  object
#  5   pagovi           172444 non-null  object
#  6   tipoagua         172444 non-null  object
#  7   naseos           172444 non-null  object
#  8   nsalones         172444 non-null  object
#  9   ndormito         172444 non-null  object
#  10  nsototrast       172444 non-null  object
#  11  notrashabit      172444 non-null  object
#  12  metrosvi         172444 non-null  object
#  13  nvehiculos       172444 non-null  object
#  14  led              172444 non-null  object
#  15  ingrehog         172444 non-null  object
# ...
